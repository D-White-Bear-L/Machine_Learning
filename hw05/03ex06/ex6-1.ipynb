# %% [markdown]
# ### 【例 6.1】
# ### 基于 BP 神经网络的银行客户流失预测。

# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot  as plt
from pylab import mpl

mpl.rcParams['font.sans-serif'] = ['STZhongsong']    # 指定默认字体：解决plot不能显示中文问题

# %%
# 读取训练数据和测试数据
df = pd.read_csv("select-data.csv")  # 加载训练数据集
df_test = pd.read_csv("scalar-test.csv")  # 加载测试数据集

print("构建向量.........")
# 构建特征向量和目标向量
train = []  # 用于存储特征数据的列表
target = []  # 用于存储目标变量的列表

# 遍历数据集中的每一行，构建特征向量
for i in range(0, len(df["EstimatedSalary"])):
    mid = []  # 临时列表，用于存储单个样本的所有特征
    
    # 依次添加各个特征
    mid.append(df["Geography"][i])      # 地理位置特征
    mid.append(df["Gender"][i])         # 性别特征
    mid.append(df["EB"][i])             # EB特征
    mid.append(df["Age"][i])            # 年龄特征
    mid.append(df["EstimatedSalary"][i])# 预估薪资特征
    mid.append(df["NumOfProducts"][i])  # 产品数量特征
    mid.append(df["CreditScore"][i])    # 信用分数特征
    mid.append(df["Tenure"][i])         # 任期特征
    mid.append(df["HasCrCard"][i])      # 是否持有信用卡特征
    mid.append(df["IsActiveMember"][i]) # 是否为活跃会员特征
    
    target.append(df["Exited"][i])      # 添加目标变量（是否流失）
    train.append(mid)                    # 将当前样本的特征向量添加到训练集

# 将列表转换为numpy数组，便于后续处理
train = np.array(train)    # 将特征数据转换为numpy数组
target = np.array(target)  # 将目标变量转换为numpy数组
# Out:
# 构建向量.........

# %%
df.head()
# Out:
#    Unnamed: 0       Age  CreditScore        EB  EstimatedSalary  Gender  \
# 0           0  0.324324        0.538  0.000000         0.506735       0
# 1           1  0.310811        0.516  0.000070         0.562709       0
# 2           2  0.324324        0.304  0.000132         0.569654       0
# 3           3  0.283784        0.698  0.000000         0.469120       0
# 4           4  0.337838        1.000  0.000150         0.395400       0
#
#    Geography  HasCrCard  IsActiveMember  NumOfProducts  Tenure  Exited
# 0        0.0          1               1       0.000000     0.2       1
# 1        0.5          0               1       0.000000     0.1       0
# 2        0.0          1               0       0.666667     0.8       1
# 3        0.0          0               0       0.333333     0.1       0
# 4        0.5          1               1       0.000000     0.2       0

# %%
df_test.head()
# Out:
#    Unnamed: 0  Geography  Gender        EB       Age  EstimatedSalary  \
# 0           0        0.0     1.0  0.000000  0.178082         0.101298
# 1           1        0.0     1.0  0.000000  0.219178         0.019060
# 2           2        0.0     0.0  0.000000  0.027397         0.644939
# 3           3        0.0     1.0  0.004121  0.287671         0.406481
# 4           4        0.5     1.0  0.001127  0.136986         0.939612
#
#    NumOfProducts  CreditScore  Tenure  HasCrCard  IsActiveMember  Exited
# 0       0.000000     0.411157     0.1        0.0             1.0     0.0
# 1       0.000000     0.419421     0.4        0.0             1.0     0.0
# 2       0.333333     0.626033     0.7        1.0             0.0     0.0
# 3       0.000000     0.677686     0.4        1.0             1.0     0.0
# 4       0.000000     0.285124     1.0        1.0             1.0     0.0

# %%
# 初始化测试数据列表和目标值列表
test = []
test_target = []

# 遍历测试数据集中的每一行
for i in range(0, len(df_test["EstimatedSalary"])):
    # 创建临时列表存储当前行的特征
    mid = []
    # 添加地理位置信息
    mid.append(df_test["Geography"][i])
    # 添加性别信息
    mid.append(df_test["Gender"][i])
    # 添加教育背景信息
    mid.append(df_test["EB"][i])
    # 添加年龄信息
    mid.append(df_test["Age"][i])
    # 添加预估薪资信息
    mid.append(df_test["EstimatedSalary"][i])
    # 添加产品数量信息
    mid.append(df_test["NumOfProducts"][i])
    # 添加信用分数信息
    mid.append(df_test["CreditScore"][i])
    # 添加任期信息
    mid.append(df_test["Tenure"][i])
    # 添加是否持有信用卡信息
    mid.append(df_test["HasCrCard"][i])
    # 添加是否活跃会员信息
    mid.append(df_test["IsActiveMember"][i])
    
    # 将当前行的目标值添加到test_target列表
    test_target.append(df_test["Exited"][i])
    # 将当前行的所有特征添加到test列表
    test.append(mid)
# 将列表转换为numpy数组以便后续处理
test = np.array(test)
test_target = np.array(test_target)
# train = np.trunc(train * 100)

# %%
# 使用sklearn.utils中的shuffle函数随机打乱训练数据和对应标签
# 这样可以避免数据的顺序性对模型训练造成影响
train, target = shuffle(train, target)

# 将标签数据重塑为二维数组形式 (n_samples, 1)
# reshape(-1,1)中的-1表示自动计算该维度的大小
target = target.reshape(-1, 1)
test_target = test_target.reshape(-1, 1)

# 使用OneHotEncoder进行独热编码转换
# 独热编码将类别型数据转换为二进制向量形式
# 例如: 类别[1,2,3] 转换为 [[1,0,0], [0,1,0], [0,0,1]]
enc = OneHotEncoder()

# 对测试集标签进行独热编码
enc.fit(test_target)  # 拟合编码器
test_target = enc.transform(test_target).toarray()  # 转换并转为密集数组

# 对训练集标签进行独热编码
enc.fit(target)  # 重新拟合编码器
target = enc.transform(target).toarray()  # 转换并转为密集数组

# 再次拟合测试集标签(注意:这行代码可能是多余的)
enc.fit(test_target)
# Out:
# OneHotEncoder()

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#import tensorflow as tf

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\baixiong\AppData\Local\Temp\ipykernel_28296\4055818224.py:6: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From c:\programme\data_science\artificial intelligence\homwork_ex\.venv\Lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#import tensorflow as tf

import tensorflow.compat.v1 as tf
tf.compat.v1.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\baixiong\AppData\Local\Temp\ipykernel_28296\1056331762.py:6: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.

# %%
# 定义输入占位符
x = tf.placeholder(tf.float32, shape=(None, 10))
# # 二分类问题 [0,1]
y = tf.placeholder(tf.float32, shape=(None, 2))
keep = tf.placeholder(tf.float32)

# 定义网络结构
# layer1
var1 = tf.Variable(tf.truncated_normal([10, 256], stddev=0.1))
bias1 = tf.Variable(tf.zeros([256]))
hc1 = tf.add(tf.matmul(x, var1), bias1)
h1 = tf.sigmoid(hc1)
h1 = tf.nn.dropout(h1, keep_prob=keep)


# layer2
var2 = tf.Variable(tf.truncated_normal([256, 256], stddev=0.1))
bias2 = tf.Variable(tf.zeros([256]))
hc2 = tf.add(tf.matmul(h1, var2), bias2)
h2 = tf.sigmoid(hc2)
h2 = tf.nn.dropout(h2, keep_prob=keep)

# layer3
var3 = tf.Variable(tf.truncated_normal([256, 2], stddev=0.1))
bias3 = tf.Variable(tf.zeros([2]))
hc3 = tf.add(tf.matmul(h2, var3), bias3)
h3 = tf.nn.softmax(hc3)
# Out:
# WARNING:tensorflow:From c:\programme\data_science\artificial intelligence\homwork_ex\.venv\Lib\site-packages\tensorflow\python\util\dispatch.py:1260: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# 定义损失
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=h3, labels=y))
tf.summary.scalar('loss', loss)

# 定义正确率
ac = tf.cast(tf.equal(tf.argmax(h3, 1), tf.argmax(y, 1)), tf.float32)
acc = tf.reduce_mean(ac)
tf.summary.scalar('accuracy', acc)

# 定义优化器
optimzer = tf.train.AdamOptimizer(1e-3).minimize(loss)

merge_summary = tf.summary.merge_all()

isTrain = 1
# Out:
# WARNING:tensorflow:From C:\Users\baixiong\AppData\Local\Temp\ipykernel_28296\1602299480.py:11: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\baixiong\AppData\Local\Temp\ipykernel_28296\1602299480.py:13: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
# 定义损失
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=h3, labels=y))
tf.summary.scalar('loss', loss)

# 定义正确率
ac = tf.cast(tf.equal(tf.argmax(h3, 1), tf.argmax(y, 1)), tf.float32)
acc = tf.reduce_mean(ac)
tf.summary.scalar('accuracy', acc)

# 定义优化器
optimzer = tf.compat.v1.train.AdamOptimizer(1e-3).minimize(loss)

merge_summary = tf.compat.v1.summary.merge_all()

isTrain = 1

# %%
# 定义训练
print("正在训练.....")
saver = tf.train.Saver(max_to_keep=1)

with tf.Session() as sess:
    if isTrain:
        init_op = tf.global_variables_initializer()
        sess.run(init_op)
        summary_writer = tf.summary.FileWriter('./logs/', sess.graph)
        nepoch=[]
        trainacc=[]
        testacc=[]
        loss1=[]
        for i in range(0, 10001):
             
            sess.run(optimzer, feed_dict={x: train, y: target, keep: 0.5})
            train_summary = sess.run(merge_summary, feed_dict={x: train, y: target, keep: 1})
            summary_writer.add_summary(train_summary, i)
           
            if i % 50 == 0:
                accu = sess.run(acc, feed_dict={x: train, y: target, keep: 1})
                accuT = sess.run(acc, feed_dict={x: test, y: test_target, keep: 1})
                losss = sess.run(loss, feed_dict={x: train, y: target, keep: 1})
               
                print("epoch:" + str(i) + "   train_acc:" + str(accu) + "   test_acc:" + str(accuT) + "   loss:" + str(
                    losss))
      
                nepoch.append(i)
                trainacc.append(accu)
                testacc.append(accuT)
                loss1.append(losss)
           
        plt.title("BP神经网络训练性能曲线")
        plt.xlabel('训练次数')
        plt.ylabel('训练样本和检验样本的准确度')
        plt.plot(nepoch,trainacc,nepoch,testacc)
        plt.plot(nepoch,trainacc,nepoch,loss1)
        plt.show()

saver.save(sess, './model/bank.ckpt', global_step=i)
# Out:
# 正在训练.....
# epoch:0   train_acc:0.49993864   test_acc:0.26   loss:0.6997368
# epoch:50   train_acc:0.6356608   test_acc:0.559   loss:0.6836501
# epoch:100   train_acc:0.63136584   test_acc:0.631   loss:0.665583
# epoch:150   train_acc:0.6336974   test_acc:0.634   loss:0.6426724
# epoch:200   train_acc:0.63517   test_acc:0.651   loss:0.6355466
# epoch:250   train_acc:0.6424101   test_acc:0.647   loss:0.63177973
# epoch:300   train_acc:0.649773   test_acc:0.658   loss:0.6289923
# epoch:350   train_acc:0.6533317   test_acc:0.66   loss:0.62627304
# epoch:400   train_acc:0.658363   test_acc:0.661   loss:0.6236794
# epoch:450   train_acc:0.6627807   test_acc:0.664   loss:0.6209134
# epoch:500   train_acc:0.6657258   test_acc:0.665   loss:0.61807877
# epoch:550   train_acc:0.6700209   test_acc:0.668   loss:0.615252
# epoch:600   train_acc:0.6737023   test_acc:0.681   loss:0.6121102
# epoch:650   train_acc:0.67787457   test_acc:0.681   loss:0.6089665
# epoch:700   train_acc:0.67812   test_acc:0.685   loss:0.6059452
# epoch:750   train_acc:0.68290585   test_acc:0.68   loss:0.60320187
# epoch:800   train_acc:0.68769175   test_acc:0.686   loss:0.6004515
# epoch:850   train_acc:0.69174135   test_acc:0.682   loss:0.5983128
# epoch:900   train_acc:0.6950546   test_acc:0.693   loss:0.5962618
# epoch:950   train_acc:0.6966499   test_acc:0.696   loss:0.59433675
# epoch:1000   train_acc:0.6977543   test_acc:0.697   loss:0.592502
# epoch:1050   train_acc:0.7005768   test_acc:0.695   loss:0.5908661
# epoch:1100   train_acc:0.7046263   test_acc:0.697   loss:0.58948815
# epoch:1150   train_acc:0.7068352   test_acc:0.698   loss:0.58774346
# epoch:1200   train_acc:0.7094122   test_acc:0.701   loss:0.5863765
# epoch:1250   train_acc:0.71162105   test_acc:0.701   loss:0.58432686
# epoch:1300   train_acc:0.7151798   test_acc:0.698   loss:0.58214486
# epoch:1350   train_acc:0.7181249   test_acc:0.701   loss:0.57959855
# epoch:1400   train_acc:0.72511965   test_acc:0.708   loss:0.57553744
# epoch:1450   train_acc:0.73100996   test_acc:0.705   loss:0.5694887
# epoch:1500   train_acc:0.7384955   test_acc:0.715   loss:0.5620445
# epoch:1550   train_acc:0.74733096   test_acc:0.725   loss:0.55481994
# epoch:1600   train_acc:0.7526077   test_acc:0.724   loss:0.54935783
# epoch:1650   train_acc:0.7562891   test_acc:0.715   loss:0.54671615
# epoch:1700   train_acc:0.75677997   test_acc:0.719   loss:0.5453093
# epoch:1750   train_acc:0.7562891   test_acc:0.72   loss:0.54443055
# epoch:1800   train_acc:0.75592095   test_acc:0.721   loss:0.54402524
# epoch:1850   train_acc:0.75567555   test_acc:0.723   loss:0.54369617
# epoch:1900   train_acc:0.755062   test_acc:0.725   loss:0.543457
# epoch:1950   train_acc:0.7561664   test_acc:0.725   loss:0.54329157
# epoch:2000   train_acc:0.7572708   test_acc:0.721   loss:0.543219
# epoch:2050   train_acc:0.7569027   test_acc:0.72   loss:0.54301363
# epoch:2100   train_acc:0.7553074   test_acc:0.721   loss:0.5428634
# epoch:2150   train_acc:0.75641185   test_acc:0.729   loss:0.54265404
# epoch:2200   train_acc:0.7572708   test_acc:0.724   loss:0.5425389
# epoch:2250   train_acc:0.757639   test_acc:0.722   loss:0.5424299
# epoch:2300   train_acc:0.75641185   test_acc:0.729   loss:0.5422961
# epoch:2350   train_acc:0.757639   test_acc:0.725   loss:0.5421775
# epoch:2400   train_acc:0.75812984   test_acc:0.719   loss:0.5421095
# epoch:2450   train_acc:0.7569027   test_acc:0.721   loss:0.54205644
# epoch:2500   train_acc:0.7570254   test_acc:0.722   loss:0.54191977
# epoch:2550   train_acc:0.75739354   test_acc:0.728   loss:0.5417825
# epoch:2600   train_acc:0.757639   test_acc:0.727   loss:0.5416796
# epoch:2650   train_acc:0.7570254   test_acc:0.725   loss:0.54161555
# epoch:2700   train_acc:0.7572708   test_acc:0.725   loss:0.54156226
# epoch:2750   train_acc:0.757639   test_acc:0.725   loss:0.54151917
# epoch:2800   train_acc:0.75739354   test_acc:0.726   loss:0.5414429
# epoch:2850   train_acc:0.7565345   test_acc:0.721   loss:0.54137176
# epoch:2900   train_acc:0.7572708   test_acc:0.728   loss:0.5412466
# epoch:2950   train_acc:0.7569027   test_acc:0.726   loss:0.5412148
# epoch:3000   train_acc:0.75739354   test_acc:0.725   loss:0.54109067
# epoch:3050   train_acc:0.7571481   test_acc:0.727   loss:0.5410174
# epoch:3100   train_acc:0.7571481   test_acc:0.728   loss:0.5409978
# epoch:3150   train_acc:0.7571481   test_acc:0.727   loss:0.54085195
# epoch:3200   train_acc:0.7565345   test_acc:0.725   loss:0.54084057
# epoch:3250   train_acc:0.7569027   test_acc:0.73   loss:0.5406966
# epoch:3300   train_acc:0.75751626   test_acc:0.728   loss:0.5405989
# epoch:3350   train_acc:0.7569027   test_acc:0.724   loss:0.54056096
# epoch:3400   train_acc:0.75665724   test_acc:0.724   loss:0.5404529
# epoch:3450   train_acc:0.75665724   test_acc:0.724   loss:0.54037064
# epoch:3500   train_acc:0.7583753   test_acc:0.732   loss:0.54028726
# epoch:3550   train_acc:0.7577617   test_acc:0.727   loss:0.54015714
# epoch:3600   train_acc:0.7569027   test_acc:0.727   loss:0.5400643
# epoch:3650   train_acc:0.7577617   test_acc:0.727   loss:0.5399391
# epoch:3700   train_acc:0.75812984   test_acc:0.727   loss:0.53984755
# epoch:3750   train_acc:0.7583753   test_acc:0.725   loss:0.53971887
# epoch:3800   train_acc:0.75997055   test_acc:0.729   loss:0.5396369
# epoch:3850   train_acc:0.7597251   test_acc:0.727   loss:0.5395112
# epoch:3900   train_acc:0.76033866   test_acc:0.73   loss:0.5393528
# epoch:3950   train_acc:0.75997055   test_acc:0.731   loss:0.53922874
# epoch:4000   train_acc:0.7609523   test_acc:0.731   loss:0.5390662
# epoch:4050   train_acc:0.7623021   test_acc:0.73   loss:0.5388122
# epoch:4100   train_acc:0.7630384   test_acc:0.732   loss:0.5385552
# epoch:4150   train_acc:0.76352924   test_acc:0.732   loss:0.5383259
# epoch:4200   train_acc:0.76438826   test_acc:0.735   loss:0.5379407
# epoch:4250   train_acc:0.764511   test_acc:0.735   loss:0.53760254
# epoch:4300   train_acc:0.76512456   test_acc:0.736   loss:0.53711057
# epoch:4350   train_acc:0.76586086   test_acc:0.737   loss:0.536407
# epoch:4400   train_acc:0.7672107   test_acc:0.739   loss:0.5355298
# epoch:4450   train_acc:0.7659836   test_acc:0.738   loss:0.5342719
# epoch:4500   train_acc:0.76659715   test_acc:0.735   loss:0.5333437
# epoch:4550   train_acc:0.76696527   test_acc:0.735   loss:0.5321296
# epoch:4600   train_acc:0.7695423   test_acc:0.737   loss:0.5311992
# epoch:4650   train_acc:0.76917416   test_acc:0.738   loss:0.53002834
# epoch:4700   train_acc:0.7697877   test_acc:0.739   loss:0.5296002
# epoch:4750   train_acc:0.77101487   test_acc:0.74   loss:0.528983
# epoch:4800   train_acc:0.77101487   test_acc:0.743   loss:0.52853656
# epoch:4850   train_acc:0.77126026   test_acc:0.742   loss:0.5283575
# epoch:4900   train_acc:0.77236474   test_acc:0.746   loss:0.5278659
# epoch:4950   train_acc:0.7732237   test_acc:0.748   loss:0.5274419
# epoch:5000   train_acc:0.77346915   test_acc:0.748   loss:0.52720785
# epoch:5050   train_acc:0.7732237   test_acc:0.749   loss:0.5269646
# epoch:5100   train_acc:0.773101   test_acc:0.75   loss:0.5266916
# epoch:5150   train_acc:0.77396   test_acc:0.749   loss:0.5265484
# epoch:5200   train_acc:0.7740827   test_acc:0.749   loss:0.52638245
# epoch:5250   train_acc:0.7746963   test_acc:0.75   loss:0.5261238
# epoch:5300   train_acc:0.77457356   test_acc:0.75   loss:0.52597654
# epoch:5350   train_acc:0.7754326   test_acc:0.748   loss:0.52580744
# epoch:5400   train_acc:0.7749417   test_acc:0.749   loss:0.52558494
# epoch:5450   train_acc:0.774819   test_acc:0.753   loss:0.52546424
# epoch:5500   train_acc:0.7743281   test_acc:0.749   loss:0.5252758
# epoch:5550   train_acc:0.775678   test_acc:0.753   loss:0.5251843
# epoch:5600   train_acc:0.774819   test_acc:0.749   loss:0.5250257
# epoch:5650   train_acc:0.77518713   test_acc:0.755   loss:0.52488047
# epoch:5700   train_acc:0.7758007   test_acc:0.755   loss:0.52473164
# epoch:5750   train_acc:0.776537   test_acc:0.755   loss:0.5245451
# epoch:5800   train_acc:0.7755553   test_acc:0.753   loss:0.5244222
# epoch:5850   train_acc:0.7758007   test_acc:0.756   loss:0.524262
# epoch:5900   train_acc:0.7755553   test_acc:0.756   loss:0.52433926
# epoch:5950   train_acc:0.7754326   test_acc:0.756   loss:0.52396035
# epoch:6000   train_acc:0.7761689   test_acc:0.758   loss:0.5239679
# epoch:6050   train_acc:0.7758007   test_acc:0.756   loss:0.5237217
# epoch:6100   train_acc:0.77629155   test_acc:0.751   loss:0.52356917
# epoch:6150   train_acc:0.7755553   test_acc:0.754   loss:0.52350163
# epoch:6200   train_acc:0.77530986   test_acc:0.755   loss:0.52329534
# epoch:6250   train_acc:0.7761689   test_acc:0.754   loss:0.5232932
# epoch:6300   train_acc:0.77604616   test_acc:0.754   loss:0.52299184
# epoch:6350   train_acc:0.7764143   test_acc:0.758   loss:0.52298784
# epoch:6400   train_acc:0.77530986   test_acc:0.755   loss:0.522735
# epoch:6450   train_acc:0.7764143   test_acc:0.757   loss:0.52264833
# epoch:6500   train_acc:0.7769051   test_acc:0.755   loss:0.52246445
# epoch:6550   train_acc:0.7769051   test_acc:0.754   loss:0.5224003
# epoch:6600   train_acc:0.7775187   test_acc:0.753   loss:0.5222561
# epoch:6650   train_acc:0.777396   test_acc:0.759   loss:0.5221003
# epoch:6700   train_acc:0.77788687   test_acc:0.757   loss:0.5219578
# epoch:6750   train_acc:0.77702785   test_acc:0.759   loss:0.521804
# epoch:6800   train_acc:0.77702785   test_acc:0.759   loss:0.5216811
# epoch:6850   train_acc:0.77702785   test_acc:0.757   loss:0.5214978
# epoch:6900   train_acc:0.77862316   test_acc:0.755   loss:0.52142817
# epoch:6950   train_acc:0.77776414   test_acc:0.759   loss:0.52119124
# epoch:7000   train_acc:0.77886856   test_acc:0.76   loss:0.5211196
# epoch:7050   train_acc:0.77935946   test_acc:0.76   loss:0.52103496
# epoch:7100   train_acc:0.7797276   test_acc:0.761   loss:0.5208753
# epoch:7150   train_acc:0.77935946   test_acc:0.753   loss:0.52072626
# epoch:7200   train_acc:0.77997303   test_acc:0.761   loss:0.5207055
# epoch:7250   train_acc:0.7798503   test_acc:0.758   loss:0.52050877
# epoch:7300   train_acc:0.7805866   test_acc:0.756   loss:0.5203371
# epoch:7350   train_acc:0.7794821   test_acc:0.758   loss:0.52025133
# epoch:7400   train_acc:0.7805866   test_acc:0.759   loss:0.5202022
# epoch:7450   train_acc:0.7805866   test_acc:0.758   loss:0.5200285
# epoch:7500   train_acc:0.780832   test_acc:0.763   loss:0.5199407
# epoch:7550   train_acc:0.78107744   test_acc:0.757   loss:0.5198227
# epoch:7600   train_acc:0.78132284   test_acc:0.76   loss:0.51963776
# epoch:7650   train_acc:0.7802184   test_acc:0.759   loss:0.5194807
# epoch:7700   train_acc:0.7800957   test_acc:0.756   loss:0.5193535
# epoch:7750   train_acc:0.780832   test_acc:0.759   loss:0.51916695
# epoch:7800   train_acc:0.78132284   test_acc:0.759   loss:0.51914454
# epoch:7850   train_acc:0.7797276   test_acc:0.757   loss:0.5189872
# epoch:7900   train_acc:0.7815683   test_acc:0.764   loss:0.51889056
# epoch:7950   train_acc:0.78034115   test_acc:0.757   loss:0.51870227
# epoch:8000   train_acc:0.78132284   test_acc:0.761   loss:0.5185497
# epoch:8050   train_acc:0.78205913   test_acc:0.765   loss:0.5185259
# epoch:8100   train_acc:0.78107744   test_acc:0.762   loss:0.5183271
# epoch:8150   train_acc:0.78144556   test_acc:0.76   loss:0.51824874
# epoch:8200   train_acc:0.7823046   test_acc:0.763   loss:0.51814747
# epoch:8250   train_acc:0.7823046   test_acc:0.765   loss:0.5180366
# epoch:8300   train_acc:0.78205913   test_acc:0.761   loss:0.5178589
# epoch:8350   train_acc:0.78218186   test_acc:0.76   loss:0.51775175
# epoch:8400   train_acc:0.7823046   test_acc:0.769   loss:0.51760274
# epoch:8450   train_acc:0.78070927   test_acc:0.759   loss:0.5174255
# epoch:8500   train_acc:0.783409   test_acc:0.766   loss:0.51735187
# epoch:8550   train_acc:0.7812002   test_acc:0.759   loss:0.51717657
# epoch:8600   train_acc:0.7826727   test_acc:0.761   loss:0.51717114
# epoch:8650   train_acc:0.7830409   test_acc:0.759   loss:0.5169335
# epoch:8700   train_acc:0.7819364   test_acc:0.766   loss:0.5169107
# epoch:8750   train_acc:0.7826727   test_acc:0.765   loss:0.51673317
# epoch:8800   train_acc:0.7832863   test_acc:0.763   loss:0.5166657
# epoch:8850   train_acc:0.78365445   test_acc:0.764   loss:0.5166275
# epoch:8900   train_acc:0.7831636   test_acc:0.762   loss:0.5165201
# epoch:8950   train_acc:0.78365445   test_acc:0.757   loss:0.51632005
# epoch:9000   train_acc:0.78402257   test_acc:0.756   loss:0.51610386
# epoch:9050   train_acc:0.7830409   test_acc:0.758   loss:0.51610136
# epoch:9100   train_acc:0.7837772   test_acc:0.757   loss:0.5158712
# epoch:9150   train_acc:0.78439075   test_acc:0.762   loss:0.5158913
# epoch:9200   train_acc:0.7848816   test_acc:0.761   loss:0.5156001
# epoch:9250   train_acc:0.7841453   test_acc:0.761   loss:0.51561016
# epoch:9300   train_acc:0.7848816   test_acc:0.759   loss:0.5155013
# epoch:9350   train_acc:0.784268   test_acc:0.757   loss:0.51541674
# epoch:9400   train_acc:0.78463614   test_acc:0.759   loss:0.51513594
# epoch:9450   train_acc:0.78549516   test_acc:0.758   loss:0.51516014
# epoch:9500   train_acc:0.78647685   test_acc:0.763   loss:0.5150704
# epoch:9550   train_acc:0.7856179   test_acc:0.755   loss:0.5148355
# epoch:9600   train_acc:0.78610873   test_acc:0.762   loss:0.5147219
# epoch:9650   train_acc:0.78623146   test_acc:0.76   loss:0.5146707
# epoch:9700   train_acc:0.7867223   test_acc:0.758   loss:0.5145249
# epoch:9750   train_acc:0.7875813   test_acc:0.76   loss:0.51441824
# epoch:9800   train_acc:0.7873359   test_acc:0.759   loss:0.51423895
# epoch:9850   train_acc:0.787704   test_acc:0.759   loss:0.5141951
# epoch:9900   train_acc:0.78794944   test_acc:0.76   loss:0.51399636
# epoch:9950   train_acc:0.7858633   test_acc:0.754   loss:0.513945
# epoch:10000   train_acc:0.7884403   test_acc:0.761   loss:0.51386863
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 64
#      62 import os
#      63 os.makedirs('./model/', exist_ok=True)
# ---> 64 saver.save(sess, './model/bank.ckpt', global_step=i)
#
# File c:\programme\data_science\artificial intelligence\homwork_ex\.venv\Lib\site-packages\tensorflow\python\training\saver.py:1288, in Saver.save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs, save_debug_info)
#    1286   model_checkpoint_path = self.saver_def.save_tensor_name
#    1287 else:
# -> 1288   model_checkpoint_path = sess.run(
#    1289       self.saver_def.save_tensor_name,
#    1290       {self.saver_def.filename_tensor_name: checkpoint_file})
#    1292 model_checkpoint_path = compat.as_str(model_checkpoint_path)
#    1293 if write_state:
#
# File c:\programme\data_science\artificial intelligence\homwork_ex\.venv\Lib\site-packages\tensorflow\python\client\session.py:977, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     974 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     976 try:
# --> 977   result = self._run(None, fetches, feed_dict, options_ptr,
#     978                      run_metadata_ptr)
#     979   if run_metadata:
#     980     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File c:\programme\data_science\artificial intelligence\homwork_ex\.venv\Lib\site-packages\tensorflow\python\client\session.py:1145, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1143 # Check session.
#    1144 if self._closed:
# -> 1145   raise RuntimeError('Attempted to use a closed Session.')
#    1146 if self.graph.version == 0:
#    1147   raise RuntimeError('The Session graph is empty. Add operations to the '
#    1148                      'graph before calling run().')
#
# RuntimeError: Attempted to use a closed Session.
